# %%
import pandas as pd
import os

# %%
os.listdir("myauthapp/accounts/data/")
# Out:
# ['calendar.csv',
#  'calendar.json',
#  'cicle.csv',
#  'cicle.json',
#  'cities.csv',
#  'cities.json',
#  'daSyao.json',
#  'daySkyVeto.json',
#  'day_sky_veto.csv',
#  'day_sky_veto.json',
#  'da_syao.csv',
#  'da_syao.json',
#  'earthLegs.json',
#  'earth_legs.csv',
#  'earth_legs.json',
#  'feitenbafa.csv',
#  'feitenbafa.json',
#  'feitenbafa_day_disp.csv',
#  'forFeitenbafa.json',
#  'forLinGuiBaFa.json',
#  'for_feitenbafa.csv',
#  'for_feitenbafa.json',
#  'for_lin_gui_ba_fa.csv',
#  'i.ipynb',
#  'images',
#  'linguibafa_df_disp.csv',
#  'moonPalace.json',
#  'moon_palace.csv',
#  'planets.csv',
#  'planets.json',
#  'preproc.xlsx',
#  'seasons.csv',
#  'seasons.json',
#  'seasons2100.json',
#  'seasons_2100.csv',
#  'seasons_orig.csv',
#  'seasons_orig.json',
#  'skyHands.json',
#  'sky_hands.csv',
#  'sky_hands.json',
#  'taiYanBaFa',
#  'tai_yan_ba_fa',
#  'veto.csv',
#  'veto.json']

# %% [markdown]
# ## Изменение данных в таблицах

# %%
file = "for_feitenbafa"
df = pd.read_csv(f"myauthapp/accounts/data/{file}.csv")
df
for c in df.columns:
    df[c] = df[c].str.replace("Жэнь", "Жень")
    df[c] = df[c].str.replace("Чун", "Чонг")
    df[c] = df[c].str.replace("цзяо", "цяо")
df
# df.to_csv(f"myauthapp/accounts/data/{file}.csv", index=False)
# Out:
#   Иероглиф     Канал         Точки
# 0        丁   Инь-цяо  Kid.6 + Lu.7
# 1        己  Жэнь-май  Lu.7 + Kid.6
# 2        辛    Ду-май  Si.3 + Bl.62
# 3        癸    Ян-цяо  Bl.62 + Si.3
# 4        乙    Ян-цяо  Bl.62 + Si.3
# 5        戊   Дай-май  Gb.41 + Th.5
# 6        庚    Ян-вэй  Th.5 + Gb.41
# 7        壬  Чонг-май   Sp.4 + Hg.6
# 8        甲  Чонг-май   Sp.4 + Hg.6
# 9        丙   Инь-вэй   Hg.6 + Sp.4

# %%
# Уменьшение длины ряда временных периодов 
times = ["01.30 - 03.00", "03.00 - 4.30", "04.30 - 5.00", "05.00 - 7.00", "07.00 - 7.30", "13.30 - 15.00", "19.00 - 19.30"]

rows = ""
for t in times:
    if len(rows) == 0:
        rows += f"{t}<br>"
    else:
        endp = int(rows.rstrip("<br>").split(" - ")[-1].split(".")[0])
        nextp = int(t.split(" - ")[0].split(".")[0])
        if endp == nextp:
            rows = rows.replace(rows.rstrip("<br>").split(" - ")[-1], t.split(" - ")[1])
        else:
            rows += f"{t}<br>"
            
print(rows)
# Out:
# 01.30 - 7.30<br>13.30 - 15.00<br>19.00 - 19.30<br>

# %%
" ".join(times).split(" - ")[-1]
# Out:
# '19.30'
