# %%
import pandas as pd
from datetime import datetime

# %%
our_date = "2025-06-16T00:00:00"
our_date_lst = our_date.split("T")[0].split("-")
our_date = datetime(int(our_date_lst[0]), int(our_date_lst[1]), int(our_date_lst[2])).date()
our_date
# Out:
# datetime.date(2025, 6, 16)

# %%
tm = datetime(2025, 2, 4, 14, 15, 0).time()
tm
# Out:
# datetime.time(14, 15)

# %%
datetime(our_date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 datetime(our_date, tm)
#
# TypeError: an integer is required (got type datetime.date)
